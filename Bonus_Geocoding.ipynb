# %%
import pandas as pd
import requests # for making requests to the google maps api
import json # for processing the response from google maps

# %%
# to retrieve api_key
with open("credentials","r") as f:
    creds = f.read()

# %% [markdown]
# ### Schools Data

# %%
school_data = pd.read_csv("./data/schools/general-information-of-schools.csv")

# %%
# take a look at the data
school_data.head()
# Out:
#                school_name                        url_address  \
# 0  NATIONAL JUNIOR COLLEGE          www.nationaljc.moe.edu.sg
# 1   TEMASEK JUNIOR COLLEGE        http://temasekjc.moe.edu.sg
# 2    JURONG JUNIOR COLLEGE     http://www.jurongjc.moe.edu.sg
# 3  ANDERSON JUNIOR COLLEGE                    ajc.moe.edu.sg.
# 4  VICTORIA JUNIOR COLLEGE  http://www.victoriajc.moe.edu.sg/
#
#                     address  postal_code telephone_no telephone_no_2  \
# 0         37 HILLCREST ROAD       288913     64661144             na
# 1       22 BEDOK SOUTH ROAD       469278     64428066             na
# 2      800 CORPORATION ROAD       649809     65624611             na
# 3  4500 ANG MO KIO AVENUE 6       569843     64596822             na
# 4           20 MARINE VISTA       449035     64485011             na
#
#      fax_no fax_no_2           email_address  \
# 0  64684535       na          NJC@MOE.EDU.SG
# 1  64428762       na   TEMASEK_JC@MOE.EDU.SG
# 2  65624505       na          jjc@moe.edu.sg
# 3  64598734       na  anderson_jc@moe.edu.sg
# 4  64438337       na  victoria_jc@moe.edu.sg
#
#                                             mrt_desc  \
# 0  BOTANIC GARDENS MRT, TAN KAH KEE MRT, SIXTH AV...
# 1                                          BEDOK MRT
# 2                                 Lakeside, Boon Lay
# 3                                       Yio Chu Kang
# 4            Nearest MRT Stations:  Kembangan, Eunos
#
#                          ...                         session_code  \
# 0                        ...                             FULL DAY
# 1                        ...                             FULL DAY
# 2                        ...                             FULL DAY
# 3                        ...                             FULL DAY
# 4                        ...                             FULL DAY
#
#    mainlevel_code sap_ind autonomous_ind gifted_ind ip_ind mothertongue1_code  \
# 0     MIXED LEVEL      No             No         No    Yes            Chinese
# 1     MIXED LEVEL      No             No         No    Yes            Chinese
# 2  JUNIOR COLLEGE      No             No         No     No            Chinese
# 3  JUNIOR COLLEGE      No             No         No     No                 na
# 4  JUNIOR COLLEGE      No             No         No    Yes            Chinese
#
#   mothertongue2_code mothertongue3_code  \
# 0              Malay              Tamil
# 1              Malay              Tamil
# 2              Malay              Tamil
# 3                 na                 na
# 4              Malay              Tamil
#
#                                  special_sdp_offered
# 0  For the Integrated Programme (Junior High), we...
# 1  TJC 6-Year Integrated Programme provides a sea...
# 2  1. Experiential Learning Programmes (ELP) 2. E...
# 3  Science research, service-learning, student le...
# 4  Arts Programme  Beyond Borders Programme Highe...
#
# [5 rows x 35 columns]

# %%
# add singapore to the end of the address so google maps returns more relevant results
school_data["address"] = school_data.address.apply(lambda x: x+ " SINGAPORE")

# %%
school_data.address.head()
# Out:
# 0           37 HILLCREST ROAD SINGAPORE
# 1         22 BEDOK SOUTH ROAD SINGAPORE
# 2        800 CORPORATION ROAD SINGAPORE
# 3    4500 ANG MO KIO AVENUE 6 SINGAPORE
# 4             20 MARINE VISTA SINGAPORE
# Name: address, dtype: object

# %%
# this function takes an address and uses google maps api to return the latitude and longitude
def geocode(address, creds):
    resp = requests.get("https://maps.googleapis.com/maps/api/geocode/json?address=" + address + "&key=" + creds)
    if len(resp.json()["results"]) == 0:
        return 0,0
    lat = resp.json()["results"][0]["geometry"]["location"]["lat"]
    lng = resp.json()["results"][0]["geometry"]["location"]["lng"]
    return lat,lng

# %%
# apply the function to the address column
coords = school_data.address.apply(lambda x: geocode(x,creds))

# %%
coords.head()
# Out:
# 0    (1.3300068, 103.8044544)
# 1    (1.3189246, 103.9355622)
# 2      (1.350886, 103.713267)
# 3     (1.378043, 103.8457619)
# 4      (1.306142, 103.919825)
# Name: address, dtype: object

# %%
# add the coordinates back to the dataframe
school_data["coords"] = coords

# %%
# select the useful columns
school_data_final = school_data[["school_name", "address", "coords", "mainlevel_code"]]

# %%
school_data_final.head()
# Out:
#                school_name                             address  \
# 0  NATIONAL JUNIOR COLLEGE         37 HILLCREST ROAD SINGAPORE
# 1   TEMASEK JUNIOR COLLEGE       22 BEDOK SOUTH ROAD SINGAPORE
# 2    JURONG JUNIOR COLLEGE      800 CORPORATION ROAD SINGAPORE
# 3  ANDERSON JUNIOR COLLEGE  4500 ANG MO KIO AVENUE 6 SINGAPORE
# 4  VICTORIA JUNIOR COLLEGE           20 MARINE VISTA SINGAPORE
#
#                      coords  mainlevel_code
# 0  (1.3300068, 103.8044544)     MIXED LEVEL
# 1  (1.3189246, 103.9355622)     MIXED LEVEL
# 2    (1.350886, 103.713267)  JUNIOR COLLEGE
# 3   (1.378043, 103.8457619)  JUNIOR COLLEGE
# 4    (1.306142, 103.919825)  JUNIOR COLLEGE

# %%
# save the new dataframe to a csv
school_data_final.to_csv("./data/schools/geocoded_school_data.csv",index=False)

# %% [markdown]
# ### Main Dataset

# %%
df = pd.read_csv("./data/hdb_prices/resale-flat-prices-based-on-registration-date-from-jan-2015-onwards.csv")

# %%
df.shape
# Out:
# (65251, 11)

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
df["full_address"] = df.block.map(str) + " " + df.street_name + " SINGAPORE"

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price                     full_address
# 0      255000.0   174 ANG MO KIO AVE 4 SINGAPORE
# 1      275000.0  541 ANG MO KIO AVE 10 SINGAPORE
# 2      285000.0   163 ANG MO KIO AVE 4 SINGAPORE
# 3      290000.0  446 ANG MO KIO AVE 10 SINGAPORE
# 4      290000.0  557 ANG MO KIO AVE 10 SINGAPORE

# %%
coords_list = []
for index, row in df.iterrows():
    try:
        coords = geocode(row.full_address, creds)
    except:
        print(index)
        coords = (0,0)
    coords_list.append([row.full_address,coords])

# %%
len(coords_list)
# Out:
# 65251

# %%
address_df = pd.DataFrame(coords_list, columns=["full_address","coords"])

# %%
address_df.to_csv("./data/hdb_prices/address_coordinates.csv", index=False)

# %%
df["address_coords"] = address_df.coords

# %%
df.shape
# Out:
# (65251, 12)

# %%
df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price                     full_address            address_coords
# 0      255000.0   174 ANG MO KIO AVE 4 SINGAPORE  (1.3752431, 103.8374311)
# 1      275000.0  541 ANG MO KIO AVE 10 SINGAPORE   (1.373289, 103.8560821)
# 2      285000.0   163 ANG MO KIO AVE 4 SINGAPORE  (1.3739926, 103.8382463)
# 3      290000.0  446 ANG MO KIO AVE 10 SINGAPORE  (1.3678117, 103.8551856)
# 4      290000.0  557 ANG MO KIO AVE 10 SINGAPORE  (1.3716063, 103.8577221)

# %%
df.to_csv("hdb_prices.csv",index=False)

# %%
pd.read_csv("./data/hdb_prices/hdb_prices.csv")
# Out:
#          month        town  flat_type block        street_name storey_range  \
# 0      2015-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1      2015-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2      2015-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3      2015-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4      2015-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5      2015-01  ANG MO KIO     3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6      2015-01  ANG MO KIO     3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7      2015-01  ANG MO KIO     3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8      2015-01  ANG MO KIO     3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9      2015-01  ANG MO KIO     3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
# 10     2015-01  ANG MO KIO     3 ROOM   218   ANG MO KIO AVE 1     07 TO 09
# 11     2015-01  ANG MO KIO     3 ROOM   556  ANG MO KIO AVE 10     10 TO 12
# 12     2015-01  ANG MO KIO     3 ROOM   156   ANG MO KIO AVE 4     10 TO 12
# 13     2015-01  ANG MO KIO     3 ROOM   471  ANG MO KIO AVE 10     07 TO 09
# 14     2015-01  ANG MO KIO     3 ROOM   434  ANG MO KIO AVE 10     07 TO 09
# 15     2015-01  ANG MO KIO     3 ROOM   560  ANG MO KIO AVE 10     07 TO 09
# 16     2015-01  ANG MO KIO     3 ROOM   332   ANG MO KIO AVE 1     10 TO 12
# 17     2015-01  ANG MO KIO     3 ROOM   421  ANG MO KIO AVE 10     01 TO 03
# 18     2015-01  ANG MO KIO     3 ROOM   506   ANG MO KIO AVE 8     07 TO 09
# 19     2015-01  ANG MO KIO     3 ROOM   631   ANG MO KIO AVE 4     07 TO 09
# 20     2015-01  ANG MO KIO     3 ROOM   153   ANG MO KIO AVE 5     10 TO 12
# 21     2015-01  ANG MO KIO     3 ROOM   442  ANG MO KIO AVE 10     10 TO 12
# 22     2015-01  ANG MO KIO     3 ROOM   558  ANG MO KIO AVE 10     10 TO 12
# 23     2015-01  ANG MO KIO     3 ROOM   212   ANG MO KIO AVE 3     10 TO 12
# 24     2015-01  ANG MO KIO     3 ROOM   152   ANG MO KIO AVE 5     04 TO 06
# 25     2015-01  ANG MO KIO     3 ROOM   331   ANG MO KIO AVE 1     04 TO 06
# 26     2015-01  ANG MO KIO     3 ROOM   121   ANG MO KIO AVE 3     07 TO 09
# 27     2015-01  ANG MO KIO     3 ROOM   130   ANG MO KIO AVE 3     07 TO 09
# 28     2015-01  ANG MO KIO     3 ROOM   564   ANG MO KIO AVE 3     07 TO 09
# 29     2015-01  ANG MO KIO     3 ROOM   646   ANG MO KIO AVE 6     07 TO 09
# ...        ...         ...        ...   ...                ...          ...
# 65221  2018-05      YISHUN     4 ROOM   637       YISHUN ST 61     10 TO 12
# 65222  2018-05      YISHUN     4 ROOM   644       YISHUN ST 61     01 TO 03
# 65223  2018-05      YISHUN     4 ROOM   715       YISHUN ST 71     01 TO 03
# 65224  2018-05      YISHUN     4 ROOM   720       YISHUN ST 71     10 TO 12
# 65225  2018-05      YISHUN     4 ROOM   720       YISHUN ST 71     04 TO 06
# 65226  2018-05      YISHUN     4 ROOM   751       YISHUN ST 72     07 TO 09
# 65227  2018-05      YISHUN     4 ROOM   749       YISHUN ST 72     07 TO 09
# 65228  2018-05      YISHUN     4 ROOM   851       YISHUN ST 81     10 TO 12
# 65229  2018-05      YISHUN     4 ROOM   816       YISHUN ST 81     04 TO 06
# 65230  2018-05      YISHUN     4 ROOM   825       YISHUN ST 81     01 TO 03
# 65231  2018-05      YISHUN     4 ROOM   868       YISHUN ST 81     01 TO 03
# 65232  2018-05      YISHUN     5 ROOM   419      YISHUN AVE 11     07 TO 09
# 65233  2018-05      YISHUN     5 ROOM   864       YISHUN AVE 4     04 TO 06
# 65234  2018-05      YISHUN     5 ROOM   663       YISHUN AVE 4     01 TO 03
# 65235  2018-05      YISHUN     5 ROOM   306        YISHUN CTRL     10 TO 12
# 65236  2018-05      YISHUN     5 ROOM   786     YISHUN RING RD     07 TO 09
# 65237  2018-05      YISHUN     5 ROOM   799     YISHUN RING RD     04 TO 06
# 65238  2018-05      YISHUN     5 ROOM   812     YISHUN RING RD     01 TO 03
# 65239  2018-05      YISHUN     5 ROOM   786     YISHUN RING RD     10 TO 12
# 65240  2018-05      YISHUN     5 ROOM   149       YISHUN ST 11     04 TO 06
# 65241  2018-05      YISHUN     5 ROOM   161       YISHUN ST 11     07 TO 09
# 65242  2018-05      YISHUN     5 ROOM   229       YISHUN ST 21     07 TO 09
# 65243  2018-05      YISHUN     5 ROOM   224       YISHUN ST 21     07 TO 09
# 65244  2018-05      YISHUN     5 ROOM   851       YISHUN ST 81     04 TO 06
# 65245  2018-05      YISHUN     5 ROOM   874       YISHUN ST 81     07 TO 09
# 65246  2018-05      YISHUN  EXECUTIVE   791       YISHUN AVE 2     04 TO 06
# 65247  2018-05      YISHUN  EXECUTIVE   328     YISHUN RING RD     07 TO 09
# 65248  2018-05      YISHUN  EXECUTIVE   352     YISHUN RING RD     10 TO 12
# 65249  2018-05      YISHUN  EXECUTIVE   723       YISHUN ST 71     10 TO 12
# 65250  2018-05      YISHUN  EXECUTIVE   828       YISHUN ST 81     07 TO 09
#
#        floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0                60.0        Improved                 1986               70
# 1                68.0  New Generation                 1981               65
# 2                69.0  New Generation                 1980               64
# 3                68.0  New Generation                 1979               63
# 4                68.0  New Generation                 1980               64
# 5                67.0  New Generation                 1980               64
# 6                68.0  New Generation                 1980               64
# 7                68.0  New Generation                 1981               65
# 8                67.0  New Generation                 1978               62
# 9                68.0  New Generation                 1985               69
# 10               67.0  New Generation                 1976               60
# 11               68.0  New Generation                 1980               64
# 12               68.0  New Generation                 1981               65
# 13               67.0  New Generation                 1979               63
# 14               67.0  New Generation                 1979               63
# 15               67.0  New Generation                 1980               64
# 16               68.0  New Generation                 1981               65
# 17               74.0  New Generation                 1979               63
# 18               68.0  New Generation                 1980               64
# 19               67.0  New Generation                 1985               69
# 20               68.0  New Generation                 1981               65
# 21               67.0  New Generation                 1979               63
# 22               67.0  New Generation                 1980               64
# 23               67.0  New Generation                 1977               61
# 24               82.0  New Generation                 1981               65
# 25               68.0  New Generation                 1981               65
# 26               67.0  New Generation                 1978               62
# 27               73.0  New Generation                 1979               63
# 28               82.0  New Generation                 1985               69
# 29               75.0  New Generation                 1980               64
# ...               ...             ...                  ...              ...
# 65221            83.0      Simplified                 1987               68
# 65222            83.0      Simplified                 1988               69
# 65223            84.0      Simplified                 1987               68
# 65224            84.0      Simplified                 1985               66
# 65225            84.0      Simplified                 1985               66
# 65226            91.0  New Generation                 1984               65
# 65227            91.0  New Generation                 1984               65
# 65228           104.0         Model A                 1988               68
